# %%
from jaad_data import JAAD
DS = JAAD(data_path='/home/dimitri/DLAV_ws/JAAD/JAAD', regen_pkl=False)

DS.generate_database()
# Out:
# ---------------------------------------------------------
# Generating database for jaad
# Getting annotations for video_0001
# Annotations found for video_0001
# Getting annotations for video_0002
# Annotations found for video_0002
# Getting annotations for video_0003
# Annotations found for video_0003
# Getting annotations for video_0004
# Annotations found for video_0004
# Getting annotations for video_0005
# Annotations found for video_0005
# Getting annotations for video_0006
# Annotations found for video_0006
# Getting annotations for video_0007
# Annotations found for video_0007
# Getting annotations for video_0008
# Annotations found for video_0008
# Getting annotations for video_0009
# Annotations found for video_0009
# Getting annotations for video_0010
# Annotations found for video_0010
# Getting annotations for video_0011
# Annotations found for video_0011
# Getting annotations for video_0012
# Annotations found for video_0012
# Getting annotations for video_0013
# ...
